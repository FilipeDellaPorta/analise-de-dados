# %% [markdown]
# <a href="https://colab.research.google.com/github/FilipeDellaPorta/analise-de-dados/blob/main/Bibliotecas_visualizacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Imigrantes do Brasil para o Canadá
#
# ---

# %% [markdown]
# ##Montando o drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Importando o pandas

# %%
import pandas as pd

# %% [markdown]
# ##Lendo e explorando os dados em csv

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/imigrantes_canada.csv')

# %%
df
# Out:
#                 País Continente            Região  1980  1981  1982  1983  \
# 0        Afeganistão       Ásia       Sul da Ásia    16    39    39    47
# 1            Albânia     Europa     Sul da Europa     1     0     0     0
# 2            Argélia     África   Norte da África    80    67    71    69
# 3    Samoa Americana    Oceânia         Polinésia     0     1     0     0
# 4            Andorra     Europa     Sul da Europa     0     0     0     0
# ..               ...        ...               ...   ...   ...   ...   ...
# 190           Vietnã       Ásia  Sudeste Asiático  1191  1829  2162  3404
# 191  Saara Ocidental     África   Norte da África     0     0     0     0
# 192            Iémen       Ásia    Ásia Ocidental     1     2     1     6
# 193           Zâmbia     África   África Oriental    11    17    11     7
# 194         Zimbábue     África   África Oriental    72   114   102    44
#
#      1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  2012  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   País        195 non-null    object
#  1   Continente  195 non-null    object
#  2   Região      195 non-null    object
#  3   1980        195 non-null    int64
#  4   1981        195 non-null    int64
#  5   1982        195 non-null    int64
#  6   1983        195 non-null    int64
#  7   1984        195 non-null    int64
#  8   1985        195 non-null    int64
#  9   1986        195 non-null    int64
#  10  1987        195 non-null    int64
#  11  1988        195 non-null    int64
#  12  1989        195 non-null    int64
#  13  1990        195 non-null    int64
#  14  1991        195 non-null    int64
#  15  1992        195 non-null    int64
#  16  1993        195 non-null    int64
#  17  1994        195 non-null    int64
#  18  1995        195 non-null    int64
# ...

# %% [markdown]
# ##Trocando os índices para a coluna de 'País'

# %%
df.set_index('País', inplace=True)

# %% [markdown]
# ##Criando a variável anos para receber uma lista com números de 1980 a 2013 em formato de string

# %%
anos = list(map(str, range(1980, 2014)))

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %% [markdown]
# ##Filtrando o DataFrame para obter os dados do Brasil, retornando os anos e os respectivos números de imigrantes

# %%
brasil = df.loc['Brasil', anos]

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brasil, dtype: object

# %% [markdown]
# ##Foi criado um dicionário com as chaves 'ano' e 'imigrantes'. Os valores correspondem, respectivamente, às listas dos índices (anos de 1980 a 2013) e dos valores (quantidade de imigrantes). Em seguida, esse dicionário foi convertido em um DataFrame

# %%
brasil_dict = {'ano': brasil.index.tolist(), 'imigrantes': brasil.values.tolist()}
dados_brasil = pd.DataFrame(brasil_dict)

# %%
dados_brasil
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %% [markdown]
# ##Importando pyplot e plotando gráfico

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4)) #valores são em polegadas, primeiro largura e depois altura
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.title('Imigração do Brasil para o Canadá')
plt.xlabel('Ano')
plt.ylabel('Nº de imigrantes')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010']) #melhorando a visualização dos labels do eixo x
plt.show() #removido as informações textuais da memória impressas #nenhuma linha depois é executada do plt.show

# %% [markdown]
# ##Fazendo o mesmo com a Argentina (desafio) e comparando com o Brasil

# %%
argentina = df.loc['Argentina', anos]
argentina_dict = {'ano': argentina.index.tolist(), 'imigrantes': argentina.values.tolist()}
dados_argentina = pd.DataFrame(argentina_dict)
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes'], label='Brasil', color='green')
plt.plot(dados_argentina['ano'], dados_argentina['imigrantes'], label='Argentina', color='blue')
plt.legend()
plt.title('Imigração para o Canadá')
plt.xlabel('Ano')
plt.xticks(['1980', '1985', '1990', '1995', '2000', '2005', '2010'])
plt.ylabel('Nº de imigrantes')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Criando uma figura

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013') #\n pula linha
ax.set_xlabel('Ano')
ax.set_ylabel('Nº de imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %% [markdown]
# ##Plotando mais de um gráfico em uma mesma figura

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 5)) #1 linha para dois gráficos um ao lado do outro #2 quantidade de gráficos
axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do Brasil para o Canadá\n1980 a 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Nº de imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5))
axs[0].grid()
axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Boxplot da imigração do Brasil para o Canadá\n1980 a 2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Nº de imigrantes')
axs[1].grid()
plt.show()

# %%
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %% [markdown]
# ##Criando subplots em duas direções

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)

axs[0, 0].plot(df.loc['Brasil', anos])
axs[0, 0].set_title('Brasil')

axs[0, 1].plot(df.loc['Colômbia', anos])
axs[0, 1].set_title('Colômbia')

axs[1, 0].plot(df.loc['Argentina', anos])
axs[1, 0].set_title('Argentina')

axs[1, 1].plot(df.loc['Peru', anos])
axs[1, 1].set_title('Peru')


for ax in axs.flat: #.flat transforma seu array 2D (ou de maior dimensão) em um iterador linear.
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  ax.set_xlabel('Ano')
  ax.set_ylabel('Nº de imigrantes')

plt.show()

# %% [markdown]
# #Arrumando a distorção no eixo y

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 6))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Imigração dos 4 maiores países da América do Sul para o Canadá\n1980 a 2013')

axs[0, 0].plot(df.loc['Brasil', anos])
axs[0, 0].set_title('Brasil')

axs[0, 1].plot(df.loc['Colômbia', anos])
axs[0, 1].set_title('Colômbia')

axs[1, 0].plot(df.loc['Argentina', anos])
axs[1, 0].set_title('Argentina')

axs[1, 1].plot(df.loc['Peru', anos])
axs[1, 1].set_title('Peru')


for ax in axs.flat:
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))
  ax.set_xlabel('Ano')
  ax.set_ylabel('Nº de imigrantes')

ymin = 0
ymax = 7000

for ax in axs.ravel(): #axs.ravel() transforma a matriz de eixos em um array 1D, o que facilita fazer um for direto em todos os subplots — igual .flat, mas retornando um array em vez de um iterador.
  ax.set_ylim(ymin, ymax)

plt.show()

# %% [markdown]
# ##Desafio com as vendas de uma loja

# %%
lojas = ['A', 'B', 'C', 'D']

vendas_2022 = {'Jan': [100, 80, 150, 50],
    'Fev': [120, 90, 170, 60],
    'Mar': [150, 100, 200, 80],
    'Abr': [180, 110, 230, 90],
    'Mai': [220, 190, 350, 200],
    'Jun': [230, 150, 280, 120],
    'Jul': [250, 170, 300, 140],
    'Ago': [260, 180, 310, 150],
    'Set': [240, 160, 290, 130],
    'Out': [220, 140, 270, 110],
    'Nov': [400, 220, 350, 190],
    'Dez': [300, 350, 400, 250]
}

vendas = pd.DataFrame(vendas_2022)
vendas['lojas'] = lojas
vendas.set_index('lojas', inplace=True)
vendas

#df = pd.DataFrame(vendas_2022, index=lojas) poderia ter sido feito assim -_-
# Out:
#        Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# lojas
# A      100  120  150  180  220  230  250  260  240  220  400  300
# B       80   90  100  110  190  150  170  180  160  140  220  350
# C      150  170  200  230  350  280  300  310  290  270  350  400
# D       50   60   80   90  200  120  140  150  130  110  190  250

# %%
vendas2 = pd.DataFrame(vendas_2022, index=lojas)
vendas2
# Out:
#    Jan  Fev  Mar  Abr  Mai  Jun  Jul  Ago  Set  Out  Nov  Dez
# A  100  120  150  180  220  230  250  260  240  220  400  300
# B   80   90  100  110  190  150  170  180  160  140  220  350
# C  150  170  200  230  350  280  300  310  290  270  350  400
# D   50   60   80   90  200  120  140  150  130  110  190  250

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 9))
fig.subplots_adjust(hspace=0.5, wspace=0.3)
fig.suptitle('Vendas no período de janeiro a dezembro de 2022 nas lojas A, B, C e D')

axs[0, 0].plot(vendas.loc['A'])
axs[0, 0].set_title('Loja A')

axs[0, 1].plot(vendas.loc['B'])
axs[0, 1].set_title('Loja B')

axs[1, 0].plot(vendas.loc['C'])
axs[1, 0].set_title('Loja C')

axs[1, 1].plot(vendas.loc['D'])
axs[1, 1].set_title('Loja D')

min = 0
max = 450

for ax in axs.ravel():
  ax.set_xlabel('Meses')
  ax.set_ylabel('Vendas')
  ax.set_ylim(min, max)
  ax.grid()

plt.show()

# %% [markdown]
# ##Voltando para a personalização do gráfico de imigração

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color='g')
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=18, loc='left')
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
plt.show()

# %% [markdown]
# ##Plotando gráfico com os países da América do Sul e avançando na estilização de gráficos

# %%
df.head()
# Out:
#                 Continente           Região  1980  1981  1982  1983  1984  \
# País
# Afeganistão           Ásia      Sul da Ásia    16    39    39    47    71
# Albânia             Europa    Sul da Europa     1     0     0     0     0
# Argélia             África  Norte da África    80    67    71    69    63
# Samoa Americana    Oceânia        Polinésia     0     1     0     0     0
# Andorra             Europa    Sul da Europa     0     0     0     0     0
#
#                  1985  1986  1987  ...  2005  2006  2007  2008  2009  2010  \
# País                               ...
# Afeganistão       340   496   741  ...  3436  3009  2652  2111  1746  1758
# Albânia             0     1     2  ...  1223   856   702   560   716   561
# Argélia            44    69   132  ...  3626  4807  3623  4005  5393  4752
# Samoa Americana     0     0     1  ...     0     1     0     0     0     0
# Andorra             0     2     0  ...     0     1     1     0     0     0
#
# ...

# %%
america_sul = df.query('Região == "América do Sul"')

# %%
america_sul
# Out:
#                           Continente          Região  1980  1981  1982  1983  \
# País
# Argentina  América Latina e o Caribe  América do Sul   368   426   626   241
# Bolívia    América Latina e o Caribe  América do Sul    44    52    42    49
# Brasil     América Latina e o Caribe  América do Sul   211   220   192   139
# Chile      América Latina e o Caribe  América do Sul  1233  1069  1078   781
# Colômbia   América Latina e o Caribe  América do Sul   266   326   360   244
# Equador    América Latina e o Caribe  América do Sul   238   207   184   155
# Guiana     América Latina e o Caribe  América do Sul  2334  2943  3575  2650
# Paraguai   América Latina e o Caribe  América do Sul    45    26    32    40
# Peru       América Latina e o Caribe  América do Sul   317   456   401   241
# Suriname   América Latina e o Caribe  América do Sul    15    10    21    12
# Uruguai    América Latina e o Caribe  América do Sul   128   132   146   105
# ...

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown', 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.bar(america_sul.index, america_sul['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('')
ax.set_ylabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid()
plt.show()

# %% [markdown]
# ##Colocando na horizontal

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.barh(america_sul.index, america_sul['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid()
plt.show()

# %% [markdown]
# ##Ordenando os valores do dataframe para que as barras horizontais fiquem do maior para o menor

# %%
america_sul_sorted = america_sul.sort_values('Total', ascending=True)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores)
ax.set_title('Imigração da América do Sul para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid()
plt.show()

# %% [markdown]
# ##Destacando informação

# %%
cores2 = []

for pais in america_sul_sorted.index:
  if pais == 'Brasil':
    cores2.append('green')
  else:
    cores2.append('silver')

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores2)
ax.set_title('América do Sul: Brasil foi o 4º país com mais imigrantes para o Canadá\nno período de 1980 a 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.grid(linestyle='--')
plt.show()

# %% [markdown]
# ##Adicionando anotações e removendo ticks e frames

# %%
for i, v in enumerate(america_sul_sorted['Total']):
  print(i, v)
# Out:
# 0 739
# 1 1944
# 2 3205
# 3 4715
# 4 12233
# 5 19596
# 6 21267
# 7 21359
# 8 29659
# 9 32652
# 10 72088
# 11 75785

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color=cores2)
ax.set_title('América do Sul: Brasil foi o 4º país com mais imigrantes para o Canadá\nno período de 1980 a 2013', loc='left', fontsize=18)
ax.set_ylabel('')
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']):
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha='left', va='center')

ax.set_frame_on(False)
ax.get_xaxis().set_visible(False)
ax.tick_params(axis='both', which='both', length=0)

plt.show()

# %%
print(fig.canvas.get_supported_filetypes())
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %% [markdown]
# ##Salvando gráficos

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color='g')
ax.set_title('Imigração do Brasil para o Canadá\n1980 a 2013', fontsize=18, loc='left')
ax.set_xlabel('Ano', fontsize=14)
ax.set_ylabel('Nº de imigrantes', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)
ax.xaxis.set_major_locator(plt.MultipleLocator(5))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

fig.savefig('imigracao_brasil_canada.png', transparent=False, dpi=300, bbox_inches='tight') #dpi é a resolução

plt.show()

# %% [markdown]
# ##Usando Seaborn

# %%
import seaborn as sns

# %%
sns.set_theme()

# %%
top_10 = df.sort_values('Total', ascending=False).head(10)

# %%
top_10
# Out:
#                                       Continente            Região   1980  \
# País
# Índia                                       Ásia       Sul da Ásia   8880
# China                                       Ásia     Ásia Oriental   5123
# Reino Unido e Irlanda do Norte            Europa   Norte da Europa  22045
# Filipinas                                   Ásia  Sudeste Asiático   6051
# Paquistão                                   Ásia       Sul da Ásia    978
# Estados Unidos da América       América do Norte  América do Norte   9378
# Irã                                         Ásia       Sul da Ásia   1172
# Sri Lanka                                   Ásia       Sul da Ásia    185
# República da Coreia                         Ásia     Ásia Oriental   1011
# Polônia                                   Europa   Europa Oriental    863
#
#                                  1981   1982   1983   1984  1985  1986   1987  \
# País
# ...

# %%
sns.barplot(data=top_10, x=top_10.index, y='Total')
# Out:
# <Axes: xlabel='País', ylabel='Total'>

# %%
sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', legend=False, hue=top_10.index) #legend=False, hue=top_10.index para ficar colorido
# Out:
# <Axes: xlabel='Total', ylabel='País'>

# %%
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', orient='h', legend=False, hue=top_10.index)
ax.set(title='Top 10 países com maior imigração para o Canadá\n1980 a 2013',
       xlabel='Nº de imigrantes',
       ylabel='')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 4))
ax = sns.barplot(data=top_10, y=top_10.index, x='Total', legend=False, hue=top_10.index)

ax.set_title('Top 10 países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=16)
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.set_ylabel('')
ax.set_axisbelow(False) #grade estava atrás
ax.grid(True, linestyle='--', color='black') #estilizando grade, isso está horrível e é só para visualização
plt.show()

# %% [markdown]
# ##Explorando paletas seaborn

# %%
def gerar_grafico_paleta(palette):
  fix,ax=plt.subplots(figsize=(8,4))
  ax=sns.barplot(data=top_10,y=top_10.index,x='Total',legend=False,hue=top_10.index,palette=palette)
  ax.set_title('Top 10 países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
  ax.set_xlabel('Nº de imigrantes', fontsize=14)
  ax.set_ylabel('')
  plt.show()

# %%
gerar_grafico_paleta('Blues')

# %%
gerar_grafico_paleta('Blues_r')

# %%
gerar_grafico_paleta('rocket')

# %%
gerar_grafico_paleta('rocket_r')

# %%
gerar_grafico_paleta('coolwarm')

# %%
gerar_grafico_paleta('coolwarm_r')

# %%
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='dark')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='whitegrid')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='white')
gerar_grafico_paleta('tab10')

# %%
sns.set_theme(style='ticks')
gerar_grafico_paleta('tab10')

# %%
fix, ax = plt.subplots(figsize=(8, 4))
ax = sns.barplot(data=top_10, y=top_10.index, hue=top_10.index, x='Total', legend=False, palette='bright') #palette para deixar as cores mais vibrantes
ax.set_title('Top 10 países com maior imigração para o Canadá\n1980 a 2013', loc='left', fontsize=18)
ax.set_xlabel('Nº de imigrantes', fontsize=14)
ax.set_ylabel('')
sns.despine()
plt.show()

# %% [markdown]
# ##Gráficos interativos com Plotly

# %%
import plotly.express as px

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Controlando o tamanho do gráfico

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes')
fig.update_layout(width=1000, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##Mexendo no eixo dos ticks

# %%
fig = px.line(dados_brasil, x='ano', y='imigrantes')
fig.update_layout(width=1000, height=500,
                  xaxis={'tickangle': -45})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
